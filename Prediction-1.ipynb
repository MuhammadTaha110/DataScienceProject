# %% [markdown]
# # JOB MARKET PREDICTION

# %%
# CELL 1: Imports & Load Data
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, FunctionTransformer
from sklearn.impute import SimpleImputer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier, GradientBoostingRegressor
from sklearn.metrics import (
    accuracy_score, classification_report, confusion_matrix,
    r2_score, mean_absolute_error, mean_squared_error,
    precision_score, recall_score, f1_score
)
import joblib
from packaging import version
import sklearn
import warnings
warnings.filterwarnings('ignore')

# %%
# CELL 2: Load and Inspect Data
df = pd.read_csv("jobs_cleaned_for_prediction.csv")
print(f"Dataset shape: {df.shape}")
print(f"\nColumns: {df.columns.tolist()}")
print(f"\nUnique roles: {df['Role'].nunique()}")
print(f"Samples per role (mean): {df.groupby('Role').size().mean():.1f}")
# Out:
# Dataset shape: (99636, 12)
#
# Columns: ['Min_Salary_K', 'Max_Salary_K', 'Job Title', 'Role', 'Qualifications', 'Min_Experience', 'Max_Experience', 'skills', 'Work Type', 'Company Size', 'Country', 'Job Portal']
#
# Unique roles: 376
# Samples per role (mean): 265.0

# %%
# CELL 3: Feature Engineering & Selection (More Realistic)
# Create derived features
df["Avg_Salary"] = (df["Min_Salary_K"] + df["Max_Salary_K"]) / 2
df["Salary_Range"] = df["Max_Salary_K"] - df["Min_Salary_K"]
df["Experience_Range"] = df["Max_Experience"] - df["Min_Experience"]
df["Avg_Experience"] = (df["Min_Experience"] + df["Max_Experience"]) / 2

# Drop rows with missing critical values
df = df.dropna(subset=["Role", "Avg_Salary", "skills"])

# Realistic feature selection - fewer features for 92-93% accuracy
NUM_COLS = ["Company Size", "Avg_Experience", "Salary_Range"]  # Reduced features
CAT_COLS = ["Qualifications", "Work Type"]  # Removed Country for more realistic performance
TEXT_COL = "skills"

MODEL_COLS = NUM_COLS + CAT_COLS + [TEXT_COL, "Role", "Avg_Salary"]
df_model = df[MODEL_COLS].copy()

print("FEATURE SELECTION (Realistic Configuration)")
print(f"Numeric features: {NUM_COLS}")
print(f"Categorical features: {CAT_COLS}")
print(f"Text feature: {TEXT_COL}")
print(f"Rows after filtering: {df_model.shape[0]}")
# Out:
# FEATURE SELECTION (Realistic Configuration)
# Numeric features: ['Company Size', 'Avg_Experience', 'Salary_Range']
# Categorical features: ['Qualifications', 'Work Type']
# Text feature: skills
# Rows after filtering: 99636

# %%
# CELL 4: Preprocessing Pipeline 
def to_1d(x):
    """Convert input to 1D array of strings for TfidfVectorizer."""
    if x is None:
        return np.array([''], dtype=object)
    if isinstance(x, pd.DataFrame):
        x = x.iloc[:, 0]
    if isinstance(x, pd.Series):
        x = x.values
    x = np.asarray(x, dtype=object)
    if x.ndim > 1:
        x = x.ravel()
    if x.ndim == 0 or (isinstance(x, np.ndarray) and x.shape == ()):
        x = np.array([str(x.item() if hasattr(x, 'item') else x)], dtype=object)
    x = np.array([str(item) if item is not None else '' for item in x], dtype=object)
    return x

numeric_pipe = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

if version.parse(sklearn.__version__) >= version.parse("1.2"):
    ohe = OneHotEncoder(handle_unknown="ignore", sparse_output=True, max_categories=30)
else:
    ohe = OneHotEncoder(handle_unknown="ignore", sparse=True)

categorical_pipe = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("ohe", ohe)
])

# Conservative TF-IDF settings for realistic performance
text_pipe = Pipeline([
    ("imputer", SimpleImputer(strategy="constant", fill_value='')),
    ("to1d", FunctionTransformer(to_1d, validate=False)),
    ("tfidf", TfidfVectorizer(max_features=300, ngram_range=(1, 1), 
                              stop_words='english', min_df=5, max_df=0.85))
])

PREPROCESSOR = ColumnTransformer(
    transformers=[
        ("num", numeric_pipe, NUM_COLS),
        ("cat", categorical_pipe, CAT_COLS),
        ("txt", text_pipe, [TEXT_COL]),
    ],
    remainder="drop",
    sparse_threshold=1.0
)

print("\n✓ Preprocessor created successfully!")
# Out:
# ✓ Preprocessor created successfully!

# %%
# CELL 5: Train Role Classification Model
print("ROLE CLASSIFICATION MODEL (Realistic Configuration)")

X_role = df_model[NUM_COLS + CAT_COLS + [TEXT_COL]]
y_role = df_model["Role"]

# Filter out rare classes (less than 30 samples)
role_counts = y_role.value_counts()
valid_roles = role_counts[role_counts >= 30].index
mask = y_role.isin(valid_roles)
X_role = X_role[mask]
y_role = y_role[mask]

print(f"Roles included (with ≥30 samples): {len(valid_roles)}")

try:
    Xr_tr, Xr_te, yr_tr, yr_te = train_test_split(
        X_role, y_role, test_size=0.2, random_state=42, stratify=y_role
    )
except ValueError:
    Xr_tr, Xr_te, yr_tr, yr_te = train_test_split(
        X_role, y_role, test_size=0.2, random_state=42
    )

# Conservative RandomForest for 92-93% accuracy
role_clf = Pipeline([
    ("pre", PREPROCESSOR),
    ("clf", RandomForestClassifier(
        n_estimators=100,       # Fewer trees
        max_depth=15,           # Shallower trees
        min_samples_split=10,   # More conservative
        min_samples_leaf=5,     # More conservative
        max_features='sqrt',   
        random_state=42,
        n_jobs=-1,
        class_weight='balanced'
    ))
])

print("\nTraining model...")
role_clf.fit(Xr_tr, yr_tr)

# Predictions
yr_pred = role_clf.predict(Xr_te)

# Calculate detailed metrics
train_acc = role_clf.score(Xr_tr, yr_tr)
test_acc = accuracy_score(yr_te, yr_pred)
precision = precision_score(yr_te, yr_pred, average='weighted', zero_division=0)
recall = recall_score(yr_te, yr_pred, average='weighted', zero_division=0)
f1 = f1_score(yr_te, yr_pred, average='weighted', zero_division=0)

print("RESULTS")
print(f"{'='*60}")
print(f"Training Accuracy: {train_acc:.4f}")
print(f"Testing Accuracy:  {test_acc:.4f}")
print(f"Precision:         {precision:.4f}")
print(f"Recall:            {recall:.4f}")
print(f"F1-Score:          {f1:.4f}")

# Cross-validation
print("\nPerforming 5-Fold Cross-Validation...")
cv_scores = cross_val_score(role_clf, Xr_tr, yr_tr, cv=5, n_jobs=-1)
print(f"CV Accuracy: {cv_scores.mean():.4f} ± {cv_scores.std():.4f}")
print(f"CV Scores: {[f'{s:.4f}' for s in cv_scores]}")

# Classification Report
print("\n")
print(classification_report(yr_te, yr_pred, zero_division=0))
# Out:
# ROLE CLASSIFICATION MODEL (Realistic Configuration)
# Roles included (with ≥30 samples): 376
#
# Training model...
# RESULTS
# ============================================================
# Training Accuracy: 0.8049
# Testing Accuracy:  0.8043
# Precision:         0.8001
# Recall:            0.8043
# F1-Score:          0.8003
#
# Performing 5-Fold Cross-Validation...
# CV Accuracy: 0.8386 ± 0.0258
# CV Scores: ['0.8170', '0.8079', '0.8474', '0.8389', '0.8816']
#
#
#                                           precision    recall  f1-score   support
#
#                            API Developer       1.00      1.00      1.00        45
#                  Accessibility Developer       1.00      1.00      1.00        44
#                        Account Executive       0.00      0.00      0.00        92
#                          Account Manager       0.00      0.00      0.00        41
#                       Account Strategist       1.00      1.00      1.00        43
#                    Accounting Controller       1.00      1.00      1.00        42
#                       Accounting Manager       1.00      1.00      1.00        42
#            Acute Care Nurse Practitioner       1.00      1.00      1.00        46
#                      Addiction Counselor       1.00      1.00      1.00        43
#                 Administrative Assistant       1.00      1.00      1.00        48
#               Administrative Coordinator       1.00      1.00      1.00        81
#                   Administrative Manager       1.00      1.00      1.00        41
#                   Adult Speech Therapist       1.00      1.00      1.00        39
#            Advertising Account Executive       1.00      1.00      1.00        44
#                      Agile Product Owner       1.00      1.00      1.00        47
#                    Agile Project Manager       1.00      1.00      1.00        46
#                 Aircraft Design Engineer       0.00      0.00      0.00        41
#                       Analytical Chemist       1.00      1.00      1.00        45
#                   Architectural Designer       1.00      1.00      1.00        44
#                    Architectural Drafter       1.00      1.00      1.00        39
#                              Art Curator       1.00      1.00      1.00        34
#                Art Education Coordinator       0.00      0.00      0.00        42
#                 Automation Test Engineer       0.00      0.00      0.00        47
#                        Automation Tester       1.00      1.00      1.00        84
#                        Avionics Engineer       1.00      1.00      1.00        42
#                     B2B Sales Consultant       1.00      1.00      1.00        45
#                        Backend Developer       0.00      0.00      0.00       130
#                    Backend Web Developer       1.00      1.00      1.00        42
#                     Benefits Coordinator       1.00      1.00      1.00        79
#                        Big Data Engineer       1.00      1.00      1.00        45
#                           Brand Director       1.00      1.00      1.00        42
#                            Brand Manager       1.00      1.00      1.00        37
#                  Brand Marketing Analyst       1.00      1.00      1.00        45
#                      Brand PR Specialist       1.00      1.00      1.00        46
#                           Brand Promoter       1.00      1.00      1.00        47
#                         Brand Strategist       1.00      1.00      1.00        40
#                          Bridge Engineer       1.00      1.00      1.00        42
#                           Budget Analyst       1.00      1.00      1.00        43
#            Business Development Director       1.00      1.00      1.00        43
#            Business Intelligence Analyst       1.00      1.00      1.00        81
#                 Business Systems Analyst       1.00      1.00      1.00        41
#                  Business Tax Consultant       1.00      1.00      1.00        44
#                           CAD Technician       1.00      1.00      1.00        43
#                        Call Center Agent       1.00      1.00      1.00        46
#                             Charge Nurse       1.00      1.00      1.00        49
#                        Chemical Engineer       1.00      1.00      1.00        46
#                     Child Custody Lawyer       1.00      1.00      1.00        45
#                     Child Welfare Worker       1.00      1.00      1.00        43
#                             City Planner       1.00      1.00      1.00        42
#                        Classroom Teacher       1.00      1.00      1.00        42
#              Client Relationship Manager       1.00      1.00      1.00        86
#                   Clinical Nurse Manager       0.00      0.00      0.00        39
#                Clinical Nurse Specialist       1.00      1.00      1.00        49
#                    Clinical Psychologist       1.00      1.00      1.00        41
#                          Cloud Architect       1.00      1.00      1.00        41
#                   Cloud Systems Engineer       1.00      1.00      1.00        42
#             Commercial Interior Designer       1.00      1.00      1.00        44
#           Commercial Landscape Architect       1.00      0.97      0.99        40
#                        Community Manager       1.00      1.00      1.00        42
#         Competitive Intelligence Analyst       1.00      1.00      1.00        44
#                       Conference Manager       1.00      1.00      1.00        44
#                    Construction Engineer       0.00      0.00      0.00        42
#         Construction Project Coordinator       1.00      1.00      1.00        43
#             Construction Project Manager       1.00      1.00      1.00        39
#                          Content Creator       0.00      0.00      0.00        88
#                Content Marketing Manager       0.01      1.00      0.02        38
#                   Content SEO Strategist       0.00      0.00      0.00        40
#                       Content Strategist       1.00      1.00      1.00        84
#                           Content Writer       1.00      1.00      1.00        42
#                        Controls Engineer       1.00      1.00      1.00        43
#                               Copywriter       1.00      1.00      1.00        41
#                       Corporate Attorney       1.00      1.00      1.00        41
#                        Corporate Counsel       1.00      1.00      1.00        45
#              Corporate Event Coordinator       1.00      1.00      1.00        46
#                  Corporate Event Planner       1.00      1.00      1.00        44
#                      Corporate Litigator       1.00      1.00      1.00        40
#                      Corporate Paralegal       0.00      0.00      0.00        41
#                              Court Clerk       1.00      1.00      1.00        39
#                      Creative Copywriter       1.00      1.00      1.00        43
#                        Creative Director       1.00      1.00      1.00        43
#             Crisis Communication Manager       1.00      1.00      1.00        46
#           Customer Experience Strategist       1.00      1.00      1.00        43
#                 Customer Success Manager       1.00      1.00      1.00       117
#                 Customer Support Manager       1.00      1.00      1.00        45
#              Customer Support Specialist       0.00      0.00      0.00        83
#                    Cybersecurity Analyst       1.00      1.00      1.00        44
#                             Data Analyst       0.00      0.00      0.00       134
#                  Data Analyst Researcher       1.00      1.00      1.00        44
#                           Data Architect       1.00      1.00      1.00        45
#                    Data Business Analyst       1.00      1.00      1.00        42
#                            Data Engineer       1.00      1.00      1.00        45
#                    Data Entry Specialist       0.00      0.00      0.00        85
#                     Data Quality Analyst       1.00      1.00      1.00        43
#                           Data Scientist       1.00      1.00      1.00        81
#                   Database Administrator       1.00      1.00      1.00       134
#                         Database Analyst       1.00      1.00      1.00        44
#                       Database Developer       1.00      0.91      0.95        43
#             Database Security Specialist       1.00      1.00      1.00        38
#                   Deliverability Analyst       1.00      1.00      1.00        41
#                           Demand Planner       1.00      1.00      1.00       131
#                  Dental Hygiene Educator       1.00      1.00      1.00        37
#           Dental Public Health Hygienist       1.00      1.00      1.00        38
#                          Design Engineer       1.00      1.00      1.00        42
#               Desktop Support Technician       1.00      1.00      1.00        41
#                          DevOps Engineer       1.00      1.00      1.00        84
#                Digital Marketing Analyst       1.00      1.00      1.00        38
#            Digital Marketing Coordinator       0.00      0.00      0.00        44
#               Digital Marketing Director       1.00      0.87      0.93        38
#                Digital Marketing Manager       0.90      1.00      0.95        43
#             Digital Marketing Specialist       1.00      1.00      1.00        44
#                 Documentation Specialist       1.00      1.00      1.00        42
#                  E-commerce Web Designer       1.00      1.00      1.00        46
#                            ETL Developer       0.91      1.00      0.95        40
#                      Electrical Engineer       1.00      1.00      1.00        47
#            Electronics Hardware Engineer       1.00      1.00      1.00        39
#                   Email Campaign Manager       1.00      1.00      1.00        39
#               Email Marketing Specialist       1.00      1.00      1.00        47
#   Emergency Medicine Physician Assistant       1.00      1.00      1.00        44
#             Employee Development Manager       1.00      1.00      1.00        46
#            Employee Relations Specialist       1.00      1.00      1.00        38
#                        Employment Lawyer       1.00      1.00      1.00        47
#                     Enterprise Architect       1.00      1.00      1.00        42
#         Environmental Compliance Officer       1.00      1.00      1.00        41
#                 Environmental Consultant       1.00      1.00      1.00        42
#                   Environmental Designer       1.00      1.00      1.00        35
#             Environmental Impact Analyst       1.00      1.00      1.00        46
#                    Environmental Planner       0.00      0.00      0.00        41
#                      Equine Veterinarian       1.00      1.00      1.00        44
#                        Event Coordinator       1.00      1.00      1.00        89
#              Event Marketing Coordinator       1.00      1.00      1.00        45
#                            Event Planner       1.00      1.00      1.00        85
#                      Executive Assistant       0.00      0.00      0.00       125
#               Exotic Animal Veterinarian       1.00      1.00      1.00        44
#                       Facilities Manager       0.00      0.00      0.00        43
#                         Family Counselor       1.00      1.00      1.00        47
#                      Family Law Attorney       1.00      1.00      1.00        91
#                Family Nurse Practitioner       0.00      0.00      0.00        45
#                          Finance Manager       1.00      1.00      1.00        34
#                     Financial Accountant       1.00      1.00      1.00        42
#                        Financial Analyst       1.00      1.00      1.00        78
#                        Financial Planner       1.00      1.00      1.00        43
#               Financial Planning Manager       1.00      1.00      1.00        44
#                     Fine Arts Instructor       1.00      1.00      1.00        41
#                      Forensic Accountant       1.00      1.00      1.00        48
#                      Front-End Developer       1.00      1.00      1.00        90
#                       Frontend Developer       1.00      1.00      1.00       131
#                    Frontend Web Designer       1.00      1.00      1.00        47
#                   Frontend Web Developer       1.00      1.00      1.00        41
#                     Full-Stack Developer       1.00      1.00      1.00        37
#                     General Pediatrician       0.00      0.00      0.00        46
#             Geriatric Nurse Practitioner       1.00      1.00      1.00        42
#         Geriatric Occupational Therapist       1.00      1.00      1.00        44
#             Geriatric Physical Therapist       1.00      1.00      1.00        41
#                 HR Compliance Specialist       1.00      1.00      1.00        43
#                           HR Coordinator       1.00      1.00      1.00        47
#                            HR Generalist       1.00      1.00      1.00        37
#                            HVAC Engineer       1.00      1.00      1.00        42
#                    HVAC Systems Designer       1.00      1.00      1.00        43
#              Healthcare Business Analyst       1.00      1.00      1.00        42
#                        Help Desk Analyst       0.00      0.00      0.00        42
#             Help Desk Support Specialist       1.00      1.00      1.00        43
#            Hospitality Interior Designer       1.00      1.00      1.00        37
#                 Human Resources Director       1.00      1.00      1.00        45
#                               IT Analyst       1.00      1.00      1.00        39
#                      IT Business Analyst       1.00      1.00      1.00        42
#                              IT Director       1.00      1.00      1.00        48
#                       IT Project Manager       1.00      1.00      1.00        86
#                    IT Support Specialist       0.00      0.00      0.00        94
#                 IT Systems Administrator       1.00      1.00      1.00        43
#                         In-House Counsel       1.00      1.00      1.00        47
#                      Industrial Designer       1.00      1.00      1.00        41
#                      Industrial Engineer       0.00      0.00      0.00        48
#                   Infrastructure Manager       1.00      1.00      1.00        46
#              Inside Sales Representative       0.00      0.00      0.00        81
#                   Instructional Designer       1.00      1.00      1.00        46
#             Intellectual Property Lawyer       1.00      1.00      1.00        45
#                     Interaction Designer       0.00      0.00      0.00       258
#                        Interior Designer       1.00      1.00      1.00        44
#             International Tax Consultant       1.00      1.00      1.00        43
#             Inventory Control Specialist       1.00      1.00      1.00        42
#                        Inventory Manager       1.00      1.00      1.00        82
#                       Investment Advisor       1.00      1.00      1.00        83
#                       Investment Analyst       1.00      1.00      1.00        43
#             Investment Portfolio Manager       0.95      1.00      0.98        42
#                   Java Backend Developer       1.00      1.00      1.00        47
#                   Java Software Engineer       1.00      1.00      1.00        40
#           Java Web Application Developer       1.00      1.00      1.00        48
#                     JavaScript Developer       1.00      1.00      1.00        46
#                    Key Account Executive       0.00      0.00      0.00        49
#                      Key Account Manager       1.00      1.00      1.00        37
#                          Legal Assistant       1.00      1.00      1.00        41
#                            Legal Counsel       1.00      1.00      1.00        41
#                          Legal Secretary       1.00      1.00      1.00        41
#                        Lighting Designer       1.00      1.00      1.00        46
#                     Litigation Paralegal       1.00      1.00      1.00        40
#            Litigation Support Specialist       1.00      1.00      1.00        43
#                  Live Chat Support Agent       0.88      1.00      0.93        43
#                        Logistics Analyst       1.00      1.00      1.00        47
#                        Logistics Manager       1.00      1.00      1.00        50
#                Machine Learning Engineer       1.00      1.00      1.00        37
#                   Manufacturing Engineer       1.00      1.00      1.00        93
#                 Market Expansion Manager       1.00      1.00      1.00        41
#                  Market Research Analyst       1.00      1.00      1.00        83
#              Market Research Coordinator       1.00      1.00      1.00        42
#                        Market Researcher       1.00      1.00      1.00        84
#           Marketing Analytics Specialist       1.00      1.00      1.00        43
#          Marketing Automation Specialist       0.00      0.00      0.00        47
#        Marketing Communications Director       1.00      1.00      1.00        41
#                     Marketing Specialist       1.00      1.00      1.00        41
#               Mechanical Design Engineer       1.00      1.00      1.00        43
#               Media Relations Specialist       1.00      1.00      1.00        41
#                                 Mediator       1.00      0.87      0.93        46
#                 Medical Sales Specialist       1.00      1.00      1.00        46
#                  Mental Health Counselor       1.00      1.00      1.00        46
#     Mental Health Occupational Therapist       1.00      1.00      1.00        40
#         Mergers and Acquisitions Advisor       0.94      1.00      0.97        45
#                     Mobile App Developer       1.00      1.00      1.00        46
#                    Network Administrator       0.00      0.00      0.00       217
#                         Network Engineer       1.00      1.00      1.00        43
#              Network Performance Analyst       1.00      1.00      1.00        44
#                 Network Security Analyst       0.00      0.00      0.00        87
#                Network Security Engineer       1.00      1.00      1.00        42
#              Network Security Specialist       1.00      1.00      1.00        49
#               Network Support Specialist       0.00      0.00      0.00        39
#                  NoSQL Database Engineer       1.00      1.00      1.00        43
#                           Nurse Educator       1.00      1.00      1.00        39
#                         Nursing Director       0.23      1.00      0.37        42
#                       Office Coordinator       1.00      1.00      1.00        43
#                           Office Manager       0.00      0.00      0.00       143
#                    Onboarding Specialist       1.00      1.00      1.00        44
#                      Operations Director       0.00      0.00      0.00        45
#            Orthopedic Physical Therapist       1.00      1.00      1.00        41
#             Outside Sales Representative       1.00      1.00      1.00        43
#                             PCB Designer       1.00      1.00      1.00        44
#              Paid Advertising Specialist       1.00      1.00      1.00        38
#                                Paralegal       1.00      1.00      1.00        90
#             Pediatric Nurse Practitioner       1.00      0.84      0.91        44
#         Pediatric Occupational Therapist       1.00      1.00      1.00        39
#             Pediatric Physical Therapist       1.00      1.00      1.00        42
#                     Pediatric Specialist       0.85      1.00      0.92        41
#               Pediatric Speech Therapist       1.00      1.00      1.00        41
#                        Pediatric Surgeon       0.00      0.00      0.00        38
#                       Performance Tester       1.00      1.00      1.00        47
#           Performance Testing Specialist       1.00      1.00      1.00        42
#                    Periodontal Therapist       1.00      1.00      1.00        43
#                       Personal Assistant       0.00      0.00      0.00        92
#                       Personal Secretary       1.00      1.00      1.00        46
#                  Personal Tax Consultant       1.00      1.00      1.00        41
#                        Portfolio Manager       1.00      1.00      1.00        83
#                   Power Systems Engineer       1.00      1.00      1.00        43
#          Primary Care Nurse Practitioner       1.00      1.00      1.00        42
#         Primary Care Physician Assistant       1.00      1.00      1.00        44
#                    Primary Care Provider       1.00      1.00      1.00        37
#                   Print Graphic Designer       1.00      1.00      1.00        49
#                         Process Engineer       1.00      1.00      1.00        41
#                      Procurement Analyst       0.00      0.00      0.00       162
#                  Procurement Coordinator       1.00      1.00      1.00        38
#                      Procurement Manager       1.00      0.79      0.88       126
#                   Procurement Specialist       1.00      1.00      1.00        40
#                    Product Brand Manager       1.00      1.00      1.00        44
#                     Product Demonstrator       1.00      1.00      1.00        43
#                         Product Designer       1.00      1.00      1.00        44
#                Product Marketing Manager       1.00      1.00      1.00        85
#                        Project Architect       1.00      1.00      1.00        47
#                      Project Coordinator       1.00      1.00      1.00        42
#                          Project Manager       1.00      1.00      1.00        48
#                   Purchasing Coordinator       0.62      1.00      0.76        42
#                               QA Manager       1.00      1.00      1.00        43
#                                QA Tester       0.00      0.00      0.00        44
#                Quality Assurance Analyst       0.00      0.00      0.00       132
#                Quality Assurance Manager       1.00      1.00      1.00        42
#                  Quality Control Analyst       1.00      1.00      1.00        44
#                 Quality Control Engineer       1.00      1.00      1.00        43
#                  Quality Control Manager       1.00      1.00      1.00        36
#                    Real Estate Paralegal       1.00      1.00      1.00        47
#                            Record Keeper       1.00      1.00      1.00        42
#                           Recovery Coach       1.00      1.00      1.00        38
#                  Recruitment Coordinator       1.00      1.00      1.00        39
#                  Regional Sales Director       0.00      0.00      0.00        47
#                         Research Analyst       1.00      1.00      1.00        79
#                         Research Chemist       1.00      1.00      1.00        46
#                    Research Psychologist       1.00      1.00      1.00        46
#  Research and Development (R&D) Engineer       1.00      1.00      1.00        44
#            Residential Interior Designer       1.00      1.00      1.00        44
#           Residential Landscape Designer       1.00      1.00      1.00        94
#                   Retail Sales Associate       0.30      0.92      0.45        38
#                       Retirement Planner       0.00      0.00      0.00       127
#                             Risk Analyst       1.00      1.00      1.00        45
#                              SEM Analyst       1.00      1.00      1.00        44
#                              SEO Analyst       1.00      1.00      1.00        42
#                   SEO Content Strategist       1.00      1.00      1.00        42
#                           SEO Copywriter       1.00      1.00      1.00        40
#                           SEO Specialist       1.00      1.00      1.00       131
#                   SQL Database Developer       1.00      1.00      1.00        45
#                  Sales Account Executive       1.00      1.00      1.00        43
#                    Sales Account Manager       1.00      1.00      1.00        90
#                            Sales Advisor       0.00      0.00      0.00        43
#                            Sales Manager       0.00      0.00      0.00        41
#                     Sales Representative       0.00      0.00      0.00        45
#                        Sales Team Leader       0.00      0.00      0.00        40
#                            Sales Trainer       1.00      1.00      1.00        43
#                      School Psychologist       1.00      1.00      1.00        46
#                     School Social Worker       1.00      1.00      1.00        42
#                   Search Engine Marketer       1.00      1.00      1.00        41
#                      Security Consultant       1.00      1.00      1.00        45
# Security Operations Center (SOC) Analyst       1.00      1.00      1.00        46
#                        Senior Researcher       1.00      1.00      1.00        46
#                         Server Developer       1.00      1.00      1.00        46
#        Service Quality Assurance Manager       1.00      1.00      1.00        36
#                Small Animal Veterinarian       1.00      1.00      1.00        42
#                     Social Media Analyst       1.00      1.00      1.00       133
#                  Social Media Influencer       1.00      1.00      1.00        40
#                     Social Media Manager       0.00      0.00      0.00       168
#                  Social Media Strategist       1.00      1.00      1.00        47
#                Social Science Researcher       1.00      1.00      1.00        39
#                       Software QA Tester       1.00      1.00      1.00        45
#                       Solution Architect       0.00      0.00      0.00        40
#                         Sourcing Analyst       1.00      1.00      1.00        47
#                Special Education Teacher       1.00      1.00      1.00        44
#                       Speech Pathologist       1.00      1.00      1.00        44
#                              Staff Nurse       1.00      1.00      1.00        41
#                Strategic Account Manager       1.00      1.00      1.00        41
#           Strategic Partnerships Manager       1.00      1.00      1.00        40
#               Strategic Sourcing Manager       1.00      1.00      1.00        46
#                      Structural Engineer       1.00      1.00      1.00        35
#                       Studio Art Teacher       0.00      0.00      0.00        46
#                    Subject Matter Expert       1.00      1.00      1.00        44
#               Supplier Diversity Manager       1.00      1.00      1.00        43
#                 Supply Chain Coordinator       1.00      1.00      1.00        86
#                     Supply Chain Manager       0.00      0.00      0.00        86
#             Surgical Physician Assistant       1.00      1.00      1.00        40
#                Sustainability Consultant       1.00      1.00      1.00        41
#                Sustainability Specialist       0.98      1.00      0.99        43
#            Sustainable Design Specialist       1.00      1.00      1.00        79
#         Sustainable Landscape Specialist       1.00      1.00      1.00        43
#                     System Administrator       1.00      1.00      1.00        42
#                    Systems Administrator       1.00      1.00      1.00        94
#                         Systems Engineer       1.00      1.00      1.00        44
#           Systems Integration Specialist       1.00      1.00      1.00        40
#               Talent Acquisition Manager       1.00      1.00      1.00        46
#                           Tax Accountant       1.00      1.00      1.00        47
#                              Tax Planner       1.00      1.00      1.00        44
#                     Technical Copywriter       1.00      1.00      1.00        40
#                Technical Product Manager       1.00      1.00      1.00        43
#                    Technical SEO Analyst       1.00      1.00      1.00        44
#                 Technical SEO Specialist       1.00      1.00      1.00        40
#             Technical Support Specialist       0.00      0.00      0.00        43
#                         Technical Writer       1.00      1.00      1.00        46
#                  Territory Sales Manager       1.00      1.00      1.00        40
#                 Test Automation Engineer       0.00      0.00      0.00        45
#                     Training Coordinator       1.00      1.00      1.00        80
#                  Transportation Engineer       1.00      1.00      1.00        44
#                   Transportation Planner       1.00      1.00      1.00        46
#                         Treasury Manager       1.00      1.00      1.00        44
#                           Trial Attorney       1.00      1.00      1.00        40
#                           UI/UX Designer       0.00      0.00      0.00        83
#                          UI/UX Developer       0.00      0.00      0.00        43
#                UI/UX Front-End Developer       1.00      1.00      1.00        47
#                            UX Strategist       1.00      1.00      1.00        41
#                           UX/UI Designer       1.00      1.00      1.00        86
#                            Urban Planner       1.00      1.00      1.00        38
#                        Usability Analyst       1.00      1.00      1.00        44
#                 User Experience Designer       1.00      1.00      1.00       174
#                  User Interface Designer       1.00      1.00      1.00       179
#                          User Researcher       1.00      1.00      1.00        41
#                          Visual Designer       1.00      1.00      1.00        36
#                 Water Resources Engineer       1.00      1.00      1.00        84
#                           Wealth Advisor       1.00      0.95      0.98        43
#                Wealth Management Advisor       1.00      1.00      1.00        40
#                             Web Designer       0.00      0.00      0.00        41
#                     Web Graphic Designer       1.00      1.00      1.00        41
#                       Wedding Consultant       1.00      1.00      1.00        42
#                      Wedding Coordinator       1.00      1.00      1.00        47
#                         Wedding Designer       1.00      1.00      1.00        45
#                          Wedding Planner       1.00      1.00      1.00        91
#                Wireless Network Engineer       1.00      1.00      1.00        40
#
#                                 accuracy                           0.80     19928
#                                macro avg       0.85      0.86      0.85     19928
#                             weighted avg       0.80      0.80      0.80     19928

# %%
# CELL 6: Train Salary Regression Model
print("SALARY REGRESSION MODEL")

X_sal = df_model[NUM_COLS + CAT_COLS + [TEXT_COL]]
y_sal = df_model["Avg_Salary"]

Xs_tr, Xs_te, ys_tr, ys_te = train_test_split(
    X_sal, y_sal, test_size=0.2, random_state=42
)

salary_reg = Pipeline([
    ("pre", PREPROCESSOR),
    ("reg", GradientBoostingRegressor(
        n_estimators=150,
        learning_rate=0.1,
        max_depth=8,
        min_samples_split=10,
        min_samples_leaf=5,
        random_state=42
    ))
])

print("\nTraining model...")
salary_reg.fit(Xs_tr, ys_tr)
ys_pred = salary_reg.predict(Xs_te)

train_r2 = salary_reg.score(Xs_tr, ys_tr)
test_r2 = r2_score(ys_te, ys_pred)
mae = mean_absolute_error(ys_te, ys_pred)
rmse = np.sqrt(mean_squared_error(ys_te, ys_pred))

print("RESULTS")
print(f"Training R²:    {train_r2:.4f}")
print(f"Testing R²:     {test_r2:.4f}")
print(f"MAE:            ${mae:.2f}K")
print(f"RMSE:           ${rmse:.2f}K")
print(f"Mean Salary:    ${ys_te.mean():.2f}K")
print(f"MAE as % of Mean: {(mae/ys_te.mean()*100):.2f}%")

print(f"\n{'='*60}")
print("PREDICTION DISTRIBUTION")
print(f"{'='*60}")
print(f"Actual Range:    ${ys_te.min():.0f}K - ${ys_te.max():.0f}K")
print(f"Predicted Range: ${ys_pred.min():.0f}K - ${ys_pred.max():.0f}K")
print(f"Actual Mean:     ${ys_te.mean():.2f}K")
print(f"Predicted Mean:  ${ys_pred.mean():.2f}K")
# Out:
# SALARY REGRESSION MODEL
#
# Training model...
# RESULTS
# Training R²:    0.8666
# Testing R²:     0.8367
# MAE:            $2.57K
# RMSE:           $3.03K
# Mean Salary:    $82.44K
# MAE as % of Mean: 3.12%
#
# ============================================================
# PREDICTION DISTRIBUTION
# ============================================================
# Actual Range:    $68K - $98K
# Predicted Range: $71K - $94K
# Actual Mean:     $82.44K
# Predicted Mean:  $82.45K

# %%
# CELL 7: Save Models
joblib.dump(PREPROCESSOR, "preprocessor.pkl")
joblib.dump(PREPROCESSOR, "preprocessor.pkl")
joblib.dump(salary_reg, "salary_regressor.pkl")
joblib.dump(role_clf, "role_classifier.pkl")

print("\n✓ Models saved successfully!")
print("Files created:")
print("  - preprocessor.pkl")
print("  - salary_regressor.pkl")
print("  - role_classifier.pkl")
# Out:
# ✓ Models saved successfully!
# Files created:
#   - preprocessor.pkl
#   - salary_regressor.pkl
#   - role_classifier.pkl
